# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/presentations']


# set creds
creds = None
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=672832104492-p6prs74jd262kj1c9ppltuk3oof9bt8h.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A55283%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fspreadsheets+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpresentations&state=qgjnL6u5NAUXA312hO0yYMHQZOVj9T&access_type=offline

# %%
import pandas as pd

# Read the data from the file
path = '2019-nats-divc-results.csv'
data = pd.read_csv(path)
# Print the data
data
# Out:
#                             Team  Overall  Total  Anatomy and Physiology  \
# 0                  Troy H.S. CA         1    231                       3
# 1                 Solon H.S. OH         2    276                       9
# 2              Harriton H.S. PA         3    277                       4
# 3                 Mason H.S. OH         4    294                       2
# 4   Pioneer H.S. (Ann Arbor) MI         5    309                      12
# ..                           ...      ...    ...                     ...
# 56      Academic Magnet H.S. SC        57   1165                      50
# 57            Cathedral H.S. MS        58   1177                      39
# 58          Kelly Walsh H.S. WY        59   1208                      58
# 59          Kaiyo Academy JP Ex        60   1224                      60
# 60  South Burlington H.S. VT Ab        61   1380                      60
#
#     Astronomy  Boomilever  Chemistry Lab  Circuit Lab  Codebusters  \
# ...

# %%
data[data.columns.difference(['Overall', "Total", "Team Penalties"])]
# Out:
#     Anatomy and Physiology  Astronomy  Boomilever  Chemistry Lab  Circuit Lab  \
# 0                        3          8          12              9            6
# 1                        9         28          10             17           14
# 2                        4         11          22              5            3
# 3                        2          9          11             11            4
# 4                       12         25           3             22            5
# ..                     ...        ...         ...            ...          ...
# 56                      50         56          55             34           44
# 57                      39         58          51             59           52
# 58                      58         38          59             54           59
# 59                      60         60          60             29           60
# 60                      60         60          60             60           60
#
# ...

# %%
one_event = data[data["Astronomy"].between(1, 10)].sort_values(by="Astronomy").filter(items=["Astronomy", "Team"]).set_index("Astronomy")
one_event
# Out:
#                             Team
# Astronomy
# 1             New Trier H.S. IL
# 2                Carmel H.S. IN
# 3                      ABRHS MA
# 4             Mira Loma H.S. CA
# 5          Madison West H.S. WI
# 6          Enloe Magnet H.S. NC
# 7            Centennial H.S. MD
# 8                  Troy H.S. CA
# 9                 Mason H.S. OH
# 10                    TJHSST VA

# %%
def create_presentation(title):
    """
        Creates the Presentation the user has access to.
        Load pre-authorized user credentials from the environment.
        TODO(developer) - See https://developers.google.com/identity
        for guides on implementing OAuth2 for the application.
        """
    # pylint: disable=maybe-no-member
    try:
        service = build('slides', 'v1', credentials=creds)

        body = {
            'title': title
        }
        presentation = service.presentations() \
            .create(body=body).execute()
        print(f"Created presentation with ID:"
              f"{(presentation.get('presentationId'))}")
        return presentation

    except HttpError as error:
        print(f"An error occurred: {error}")
        print("presentation not created")
        return error


if __name__ == '__main__':
    # Put the title of the presentation

    create_presentation("finalp")
# Out:
# Created presentation with ID:1uPWaH8z4_QQPn8ba2Ui8N2FmRrOz3EL8GP7YPoTNve4
